# %% [markdown]
# # LS_ML Assignment 2
# ## YOLOv8

# %% [markdown]
# ### Checking the GPU

# %%
# !nvidia-smi
# Out:
# Tue Jul 16 10:39:06 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# ### Installing Ultralytics

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.58 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.1/107.7 GB disk)

# %% [markdown]
# ### Necessary Imports

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# ### Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Changing Directory to the directory with data

# %%
# %cd /content/drive/MyDrive/car
# Out:
# /content/drive/MyDrive/car

# %% [markdown]
# ### Training the model

# %%
model = YOLO('yolov8s.pt')
model.train(data='data.yaml', epochs=25, imgsz=224, plots=True)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 70.5MB/s]
# Ultralytics YOLOv8.2.58 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %% [markdown]
# ## The Confusion Matrix

# %%
Image(filename='runs/detect/train/confusion_matrix.png', width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 681, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 149, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 230, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 855, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
# ...

# %%
model = YOLO('/content/drive/MyDrive/car/runs/detect/train/weights/best.pt')
results = model.predict(source='/content/drive/MyDrive/car/test/images', save=True)
# Out:
# image 1/22 /content/drive/MyDrive/car/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg: 224x224 1 car, 1 license_plate, 145.2ms
# image 2/22 /content/drive/MyDrive/car/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg: 224x224 3 cars, 1 license_plate, 103.8ms
# image 3/22 /content/drive/MyDrive/car/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg: 224x224 2 cars, 1 license_plate, 105.6ms
# image 4/22 /content/drive/MyDrive/car/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg: 224x224 1 car, 1 license_plate, 1 rear_bumper, 109.1ms
# image 5/22 /content/drive/MyDrive/car/test/images/Cars306_png.rf.dd001ad2f0e6c305bf5bd3d704eebd75.jpg: 224x224 2 cars, 1 license_plate, 111.0ms
# image 6/22 /content/drive/MyDrive/car/test/images/Cars343_png.rf.1faf32b05c2b6bb56b93e41b49b56db9.jpg: 224x224 1 car, 2 license_plates, 108.8ms
# ...

# %% [markdown]
# ## Results.png

# %%
Image(filename='/content/drive/MyDrive/car/runs/detect/train/results.png', width=1200)
