# %% [markdown]
# # Binary Classification of Images using Neural Network

# %% [markdown]
# ### Necessary Imports

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import numpy as np
import os
from PIL import Image

# %% [markdown]
# ### Defining size of image and batch size

# %%
img_width = 64
img_height = 64
batch_size = 32

# %% [markdown]
# ### Function to load Images

# %%
def load_images(folder):
  images = []
  labels = []
  class_names = os.listdir(folder)
  for class_idx,class_name in enumerate(class_names):
    class_folder = os.path.join(folder,class_name)
    for img in os.listdir(class_folder):
      img_path = os.path.join(class_folder,img)
      img = Image.open(img_path).resize((img_width, img_height))
      img = np.array(img)
      images.append(img)
      labels.append(class_idx)
  return images,labels

# %% [markdown]
# ### Mounting the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Loading the iamge

# %%
images, labels = load_images('/content/drive/MyDrive/homer_bart')
images = np.array(images) / 255.0

# %% [markdown]
# ### Splitting the training set and test set and converting the labels to one hot encoding

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.1, random_state=123)
y_train = keras.utils.to_categorical(y_train, num_classes=2)
y_test = keras.utils.to_categorical(y_test, num_classes=2)

# %% [markdown]
# ### Model

# %%
inputs = keras.Input(shape=(img_width,img_height,3))
x = layers.Flatten()(inputs)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(2, activation='sigmoid')(x)
model = keras.Model(inputs=inputs,outputs=outputs)

# %%
model.compile(
    loss = keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.001),
    metrics = ["accuracy"]
)

# %% [markdown]
# ### Training

# %%
model.fit(X_train, y_train,batch_size=batch_size,epochs=20)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0977 - accuracy: 0.9711
# Epoch 2/20
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0926 - accuracy: 0.9835
# Epoch 3/20
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0969 - accuracy: 0.9711
# Epoch 4/20
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2580 - accuracy: 0.8719
# Epoch 5/20
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1017 - accuracy: 0.9752
# Epoch 6/20
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0881 - accuracy: 0.9711
# Epoch 7/20
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0895 - accuracy: 0.9752
# Epoch 8/20
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0946 - accuracy: 0.9669
# Epoch 9/20
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0764 - accuracy: 0.9752
# Epoch 10/20
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0619 - accuracy: 0.9959
# Epoch 11/20
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0420 - accuracy: 1.0000
# Epoch 12/20
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 13/20
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 14/20
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 15/20
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 16/20
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 17/20
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0491 - accuracy: 0.9959
# Epoch 18/20
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0593 - accuracy: 1.0000
# Epoch 19/20
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 20/20
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0256 - accuracy: 1.0000

# %% [markdown]
# ### Testing

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4755 - accuracy: 0.8148
# Test accuracy: 0.8148
